# %%
import numpy as np

x = np.array([[1, 2],
             [1, 3]])

eigenvector, eigenvalue = np.linalg.eig(x)

print("Eigenvector: ", eigenvector)

print("Eigenvalue: ", eigenvalue)
# Out:
# Eigenvector:  [0.26794919+0.j 3.73205081+0.j]
# Eigenvalue:  [[-0.9390708 +0.j -0.59069049+0.j]
#  [ 0.34372377+0.j -0.80689822+0.j]]
