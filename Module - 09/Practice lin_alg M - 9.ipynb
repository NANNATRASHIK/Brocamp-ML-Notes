# %%
def multi3(A, B):
    result = [[0 for i in range(len(B[0]))] for j in range(len(A))]

    for i in range(len(A)):
        for j in range(len(B[0])):
            for k in range(len(B)):
                result[i][j] += A[i][k] * B[k][j]

    return result

A = [[20, 1, 3],
    [4, 0, 1]]

B = [[1, 6],
    [3, 4],
    [5, 6]]

print(multi3(A, B))
# Out:
# [[38, 142], [9, 30]]

# %%
def det3(m):
    det = (m[0][0] * ((m[1][1] * m[2][2]) - (m[1][2] * m[2][1])))
        - (m[0][1] * ((m[1][0] * m[2][2]) - (m[2][0] * m[1][2])))
        + (m[0][2] * ((m[1][0] * m[2][1]) - (m[1][1] * m[2][0])))
        
    return det

A = [[1, 2 ,3],
    [4, 5, 6],
    [7, 8, 9]]

print(det3(A))
# Out:
# 0

# %%
def det2(m):
    det = (m[0][0] * m[1][1]) - (m[1][0] * m[0][1])

    return det


A = [[1, 2],
    [3, 4]]

print(det2(A))
# Out:
# -2

# %%
def add(A, B):
    
    n = len(A)

    sum = [[0 for i in range(n)] for j in range(n)]

    for i in range(n):
        for j in range(n):
            sum[i][j] = A[i][j] + B[i][j]

    return sum

A = [[1, 2, 3],
    [1, 2, 4],
    [3, 6, 9]]

B = [[1, 2, 3],
    [1, 2, 4],
    [3, 6, 9]]

print(add(A, B))
# Out:
# [[2, 4, 6], [2, 4, 8], [6, 12, 18]]

# %%
def inv2(matrix):

    det = matrix[0][0] * matrix[1][1] - matrix[0][1] * matrix[1][0]

    return [
        [matrix[1][1]/det, -matrix[0][1]/det],
        [-matrix[1][0]/det, matrix[0][0]/det]
    ]

A = [[1, 2],
    [3, 4]]

print(inv2(A))
# Out:
# [[-2.0, 1.0], [1.5, -0.5]]

# %%
def eigen2(A):

    a1 = A[0][0]
    b1 = A[0][1]
    c1 = A[1][0]
    d1 = A[1][1]

    t = a1 + d1

    det = a1 * d1 - b1 * c1

    dis = t * t - 4 * det

    if dis < 0:
        print("Complex Eigenvalue")
        return

    s = dis ** 0.5

    l1 = (t + s)/2
    l2 = (t - s)/2

    print("Eigenvalues 1: ", l1)
    print("Eigenvalues 2: ", l2)

    print()

    print("Eigenvector for ", l1)

    if b1 != 0:
        x = 1
        y = (l1 - a1)/b1
    elif c1 != 0:
        y = 1
        x= (l1 - d1)/c1
    else:
        x = 1
        y = 0

    print([x, y])

    print("Eigenvectors for ", l2)

    if b1 != 0:
        x = 1
        y = (l1 - a1)/b1

    elif c1 != 0:
        y = 1
        x = (l2 - d1)/c1
    else:
        x = 1
        y = 0

    print([x, y])

A = [[4, 2],
    [1, 3]]

eigen2(A)
# Out:
# Eigenvalues 1:  5.0
# Eigenvalues 2:  2.0
#
# Eigenvector for  5.0
# [1, 0.5]
# Eigenvectors for  2.0
# [1, 0.5]

# %%
def gradient_descend(x, lr, itr):
    for i in range(itr):
        gradient = 2 * x
        x -= lr * gradient

    return x

print(gradient_descend(10, 0.1, 100))
# Out:
# 2.0370359763344878e-09

# %%
def eigen2(m):
    a1 = m[0][0]
    b1 = m[0][1]
    c1 = m[1][0]
    d1 = m[1][1]

    t = a1 + d1

    det = a1 * d1 - b1 * c1

    dis = t * t - 4 * det

    if dis < 0:
        print("Eigenvalue is complex")
        return

    s = dis ** 0.5

    l1 = (t + s)/2
    l2 = (t - s)/2

    print("Eigenvalue 1: ", l1)
    print("Eigenvalue 2: ", l2)

    print()

    print("Eigenvector of ", l1)

    if b1 != 0:
        x = 1
        y = (l1 - a1)/b1
    elif c1 != 0:
        y = 1
        x = (l1 - c1)/d1
    else:
        x = 1
        y = 0

    print([x, y])

    print("Eigenvector of ", l2)

    if b1 != 0:
        x = 1
        y = (l2 - a1)/b1
    elif c1 != 0:
        y = 1
        x = (l2 - d1)/c1
    else:
        x = 1
        y = 1

    print([x, y])

a = [
    [4, 2],
    [1, 3]
]

eigen2(a)
# Out:
# Eigenvalue 1:  5.0
# Eigenvalue 2:  2.0
#
# Eigenvector of  5.0
# [1, 0.5]
# Eigenvector of  2.0
# [1, -1.0]

# %%
def transpose(A):

    n = len(A)

    for i in range(n):
        for j in range(i + 1, n):
            A[i][j], A[j][i] = A[j][i], A[i][j]

    return A

A = [[1, 3],
    [4, 9]]

for row in transpose(A):
    print(row)
# Out:
# [1, 4]
# [3, 9]

# %%
def mulitiple3(A, B):
    result = [[0 for i in range(len(B[0]))] for j in range(len(A))]

    for i in range(len(A)):
        for j in range(len(B[0])):
            for k in range(len(B)):
                result[i][j] += A[i][k] * B[k][j]

    return result

A = [[20, 1, 3],
    [4, 0, 1]]

B = [[1, 6],
    [3, 4],
    [5, 6]]

mulitiple3(A, B)
# Out:
# [[38, 142], [9, 30]]

# %%
def add(A, B):
    n = len(A)

    result = [[0 for i in range(n)] for j in range(n)]

    for i in range(n):
        for j in range(n):
            result[i][j] = A[i][j] + B[i][j]

    return result

A = [[1, 3],
    [4, 9]]

B = [[1, 6],
    [3, 4]]

for row in add(A, B):
    print(row)
# Out:
# [2, 9]
# [7, 13]

# %%
import matplotlib.pyplot as plt
import numpy as np

def gradient_descend(x, lr, itr):

    history = []
    
    for i in range(itr):

        history.append(x)
        
        gradient = x * 2
        x -= lr * gradient
    return history

history = gradient_descend(10, 0.1, 20)

x = np.linspace(-11, 11, 400)
y = x ** 2

plt.plot(x, y)

plt.scatter(history, [i**2 for i in history], color="red")
plt.plot(history, [i**2 for i in history])

# %%
import numpy as np
import pandas as pd

X = pd.read_csv("PCA.csv")


# Step 1
mean = np.mean(X, axis=0)

# Step 2
X_centered = X - mean

# Step 3
cov_matrix = np.cov(X_centered.T)

# Step 4
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Step 5
pc1 = eigenvectors[:, 0]
X_pca = X_centered @ pc1

print(X_pca)
# Out:
# 0      5.995797+ 0.000000j
# 1      1.179244+ 0.000000j
# 2     13.258987+ 0.000000j
# 3    -14.762592+ 0.000000j
# 4     -6.148001+ 0.000000j
# 5     17.201181+ 0.000000j
# 6    -11.041703+ 0.000000j
# 7      8.187059+ 0.000000j
# 8    -21.134986+ 0.000000j
# 9      3.616171+ 0.000000j
# 10    12.486136+ 0.000000j
# 11    -6.554260+ 0.000000j
# 12    -3.062533+ 0.000000j
# 13    15.527396+ 0.000000j
# 14   -16.580535+ 0.000000j
# 15    -0.063922+ 0.000000j
# 16   -10.258714+ 0.000000j
# 17    19.580808+ 0.000000j
# 18   -13.232964+ 0.000000j
# 19     5.807432+ 0.000000j
# dtype: complex128

# %%
def eigen2(matrix):
    a1 = matrix[0][0]
    b1 = matrix[0][1]
    c1 = matrix[1][0]
    d1 = matrix[1][1]

    t = a1 + d1

    det = a1 * d1 - c1 * b1

    dis = t * t - 4 * det

    if dis < 0:
        print("Eigenvalue is Complex")
        return

    s = dis ** 0.5

    l1 = (t + s)/2
    l2 = (t - s)/2

    print("Eigenvalue 1: ", l1)
    print("Eigenvalue 2: ", l2)

    print()

    print("Eigenvector of ", l1)
    
    if b1 != 0:
        x = 1
        y = (l1 - a1)/b1
    elif c1 != 0:
        y = 1
        x = (l2 - d1)/c1
    else:
        x = 1
        y = 0

    print([x, y])

    print("Eigenvector of ", l2)

    if b1 != 0:
        x = 1
        y = (l2 - a1)/b1
    elif c1 != 0:
        y = 1
        x = (l2 - d1)/c1
    else:
        x = 1
        y = 0

    print([x, y])

a = [
    [4, 2],
    [1, 3]
]

eigen2(a)
# Out:
# Eigenvalue 1:  5.0
# Eigenvalue 2:  2.0
#
# Eigenvector of  5.0
# [1, 0.5]
# Eigenvector of  2.0
# [1, -1.0]

# %%
def gradient_decsend(x, lr, itr):
    for i in range(itr):
        gradient = 2 * x
        x -= lr * gradient

    return x

print(gradient_decsend(10, 0.1, 100))
# Out:
# 2.0370359763344878e-09

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_decsend(x, lr, itr):
    history = []

    for i in range(itr):

        history.append(x)
        
        gradient = 2 * x
        x -= lr * gradient

    return history

histroy = gradient_decsend(10, 0.1, 100)

x = np.linspace(-11, 11, 400)
y = x ** 2
plt.plot(x, y)

plt.scatter(history, [i**2 for i in history], color = "red", marker="*")
plt.plot(history, [i**2 for i in history])

plt.plot()
plt.xlabel("x")
plt.ylabel("f(x)")
# Out:
# Text(0, 0.5, 'f(x)')

# %%
X = np.array([
    [2.5, 2.4],
    [0.5, 0.7],
    [2.2, 2.9],
    [1.9, 2.2],
    [3.1, 3.0]
])

mean = np.mean(X)
centered = X - mean

cov_matrix = np.cov(centered.T)

eigenvalue, eigenvector = np.linalg.eig(cov_matrix)

pc1 = eigenvector[:, 0]
X_pca = centered @ pc1

print(X_pca)
# Out:
# [ 0.44005237+0.j -2.18076612+0.j  0.56714032+0.j -0.13259672+0.j
#   1.28830979+0.j]

# %%
def add(A, B):
    n = len(A)
    
    result = [[0 for i in range(n)] for i in range(n)]

    for i in range(n):
        for j in range(n):
            result[i][j] = A[i][j] + B[i][j]

    return result

A = [[1, 2],
    [4, 8]]

B = [[3, 8],
    [9, 5]]

print(add(A, B))
# Out:
# [[4, 10], [13, 13]]

# %%
def multi3(A, B):

    result = [[0 for i in range(len(B[0]))] for j in range(len(A))]

    for i in range(len(A)):
        for j in range(len(B[0])):
            for k in range(len(B)):
                result[i][j] += A[i][k] * B[k][j]
    return result

A = [[20, 1, 3],
    [4, 0, 1]]

B = [[1, 6],
    [3, 4],
    [5, 6]]


print(multi3(A, B))
# Out:
# [[38, 142], [9, 30]]

# %%
def transpose(A):
    n = len(A)

    for i in range(n):
        for j in range(i + 1, n):
            A[i][j], A[j][i] = A[j][i], A[i][j]

    return A

A = [[1, 3],
    [4, 9]]

for row in transpose(A):
    print(row)
# Out:
# [1, 4]
# [3, 9]

# %%
def inv(A):

    return [
        [A[1][1], -A[0][1]],
        [-A[1][0], A[0][0]]
    ]

A = [[1, 3],
    [4, 9]]

inv(A)
# Out:
# [[9, -3], [-4, 1]]

# %%
def eigen2(A):
    a1 = A[0][0]
    b1 = A[0][1]
    c1 = A[1][0]
    d1 = A[1][1]

    t = a1 + d1

    det = a1*d1 - b1*c1

    dis = t * t - 4 * det

    if dis < 0:
        print("The Eigenvalues is complex")
        return

    print()
    
    s = dis ** 0.5

    l1 = (t + s)/2
    l2 = (t - s)/2

    print("Eigenvalues: ", l1)
    print("Eigenvalues: ", l2)

    print()

    print("Eigenvector of: ", l1)

    if b1 != 0:
        x = 1
        y = (l1 - a1)/b1
    elif c1 != 0:
        y = 1
        x = (l2 - d1)/c1
    else:
        x = 1
        y = 0

    print([x, y])

    print("Eigenvector of: ", l2)

    if b1 != 0:
        x = 1
        y = (l1 - a1)/b1
    elif c1 != 0:
        y = 1
        x = (l2 - d1)/c1
    else:
        x = 1
        y = 0

    print([x, y])

a = [
    [4, 2],
    [1, 3]
]

eigen2(a)
# Out:
# Eigenvalues:  5.0
# Eigenvalues:  2.0
#
# Eigenvector of:  5.0
# [1, 0.5]
# Eigenvector of:  2.0
# [1, 0.5]

# %%
def gradient_descend(x, lr, itr):
    for i in range(itr):
        gradient = 2 * x
        x -= lr * gradient

    return x
    
print(gradient_descend(10, 0.01, 10000))
# Out:
# 1.822875151717797e-87

# %%
import numpy as np

X = np.array([
    [2.5, 2.4],
    [0.5, 0.7],
    [2.2, 2.9],
    [1.9, 2.2],
    [3.1, 3.0]
])

mean = np.mean(X)

x_center = X - mean

x_cov = np.cov(x_center.T)

eigenvalues, eigenvector = np.linalg.eig(x_cov)

pc1 = eigenvector[:, 0]

pca = x_center @ pc1

print(pca)
# Out:
# [ 0.44005237+0.j -2.18076612+0.j  0.56714032+0.j -0.13259672+0.j
#   1.28830979+0.j]

# %%
import numpy as np

X = np.array([
    [2.5, 2.4],
    [0.5, 0.7],
    [2.2, 2.9],
    [1.9, 2.2],
    [3.1, 3.0]
])

mean = np.mean(X)

x_centered = X - mean

x_cov = np.cov(x_centered.T)

eigenvalues, eigenvecotor = np.linalg.eig(x_cov)

pc1 = eigenvector[:, 0]

pca = x_centered @ pc1

print(pca)
# Out:
# [ 0.44005237+0.j -2.18076612+0.j  0.56714032+0.j -0.13259672+0.j
#   1.28830979+0.j]

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descend(x, lr, itr):

    history = []
    
    for i in range(itr):
        gradient = 2 * x
        x -= lr * gradient

        history.append(x)

    return history

history = gradient_descend(10, 0.1, 100)

x = np.linspace(-11, 11, 400)
y = x ** 2
plt.plot(x, y)

plt.scatter(history, [i**2 for i in history], color="green", marker="*")
plt.plot(history, [i**2 for i in history])

# %%
def det3(A):
    a1 = A[0][0]
    a2 = A[0][1]
    a3 = A[0][2]

    b1 = A[1][0]
    b2 = A[1][1]
    b3 = A[1][2]

    c1 = A[2][0]
    c2 = A[2][1]
    c3 = A[2][2]

    det = (a1*((b2*c3)-(b3*c2)) - a2*((b1*c3)-(b3*c1)) + a3*((b1*c2)-(b2*c1)))

    return det

A = [[1, 2 ,3],
    [4, 5, 6],
    [7, 8, 9]]


print(det3(A))
# Out:
# 0

# %%
def multi3(A, B):

    result = [[0 for i in range(len(B[0]))] for i in range(len(A))]

    for i in range(len(A)):
        for j in range(len(B[0])):
            for k in range(len(B)):
                result[i][j] += A[i][k] * B[k][j]

    return result

A = [[20, 1],
    [4, 0]]

B = [[1, 6],
    [3, 4]]

print(multi3(B, A))
# Out:
# [[44, 1], [76, 3]]

# %%
def add(A, B):

    n = len(A)

    result = [[0 for i in range(n)] for j in range(n)]

    for i in range(n):
        for j in range(n):
             result[i][j] = A[i][j] + B[i][j]

    return result

A = [[20, 1],
    [4, 0]]

B = [[1, 6],
    [3, 4]]

print(add(A, B))
# Out:
# [[21, 7], [7, 4]]

# %%
import numpy as np
import matplotlib.pyplot as plt

def gradient_descend(x, lr, itr):

    history = []
    
    for i in range(itr):
        gradient = 2 * x
        x -= lr * gradient
        history.append(x)

    return history


history = gradient_descend(10, 0.1,100)

x = np.linspace(-11, 11, 400)
y = x ** 2
plt.plot(x, y)

plt.scatter(history, [i**2 for i in history], color="red", marker="*")
plt.plot(history, [i**2 for i in history])

plt.show()

# %%
import numpy as np
import pandas as pd

X = pd.read_csv("PCA.csv")
X.values

mean = np.mean(X, axis=0)
x_center = X - mean

cov_matrix = np.cov(x_center.T)

eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

idx = np.argsort(eigenvalues)

eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

pc = eigenvector[:, :2]

pca = x_center @ pc

print(pca)
# Out:
#                        0                   1
# 0    5.995797+ 0.000000j  0.960314+0.000000j
# 1    1.179244+ 0.000000j  1.684101+0.000000j
# 2   13.258987+ 0.000000j -0.154490+0.000000j
# 3  -14.762592+ 0.000000j  0.032188+0.000000j
# 4   -6.148001+ 0.000000j -0.991686+0.000000j
# 5   17.201181+ 0.000000j -0.560236+0.000000j
# 6  -11.041703+ 0.000000j -0.983231+0.000000j
# 7    8.187059+ 0.000000j  0.004433+0.000000j
# 8  -21.134986+ 0.000000j -0.328714+0.000000j
# 9    3.616171+ 0.000000j  0.530337+0.000000j
# 10  12.486136+ 0.000000j  0.071328+0.000000j
# 11  -6.554260+ 0.000000j  0.469522+0.000000j
# 12  -3.062533+ 0.000000j  0.033465+0.000000j
# 13  15.527396+ 0.000000j -0.395038+0.000000j
# 14 -16.580535+ 0.000000j  0.303046+0.000000j
# 15  -0.063922+ 0.000000j -0.419464+0.000000j
# 16 -10.258714+ 0.000000j  0.327276+0.000000j
# 17  19.580808+ 0.000000j -0.130259+0.000000j
# 18 -13.232964+ 0.000000j -0.027350+0.000000j
# 19   5.807432+ 0.000000j -0.425544+0.000000j

# %%
import numpy as np
import pandas as pd

X = pd.read_csv("PCA.csv")
X = X.values

mean = np.mean(X, axis=0)
X_centered = X - mean

cov_matrix = np.cov(X_centered.T)

eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

idx = np.argsort(eigenvalues)[::-1]

eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

principal_components = eigenvectors[:, :2]

X_pca = X_centered @ principal_components

print("Original Shape:", X.shape)
print("Reduced Shape:", X_pca.shape)

print(eigenvalues)
print(principal_components)
print(X_pca)
# Out:
# Original Shape: (20, 5)
# Reduced Shape: (20, 2)
# [1.49221645e+02+0.j 3.89110254e-01+0.j 2.27258212e-01+0.j
#  1.58903172e-01+0.j 5.83465610e-02+0.j]
# [[-0.45046715+0.j -0.03030993+0.j]
#  [-0.51747633+0.j  0.79068269+0.j]
#  [-0.14415709+0.j  0.10566041+0.j]
#  [-0.1015085 +0.j  0.09222312+0.j]
#  [-0.70584159+0.j -0.59517473+0.j]]
# [[ 5.99579741e+00+0.j  9.60313901e-01+0.j]
#  [ 1.17924376e+00+0.j  1.68410146e+00+0.j]
#  [ 1.32589869e+01+0.j -1.54489580e-01+0.j]
#  [-1.47625924e+01+0.j  3.21876212e-02+0.j]
#  [-6.14800149e+00+0.j -9.91686066e-01+0.j]
#  [ 1.72011813e+01+0.j -5.60236124e-01+0.j]
#  [-1.10417031e+01+0.j -9.83230725e-01+0.j]
#  [ 8.18705882e+00+0.j  4.43317511e-03+0.j]
#  [-2.11349864e+01+0.j -3.28713874e-01+0.j]
#  [ 3.61617075e+00+0.j  5.30337202e-01+0.j]
#  [ 1.24861361e+01+0.j  7.13283144e-02+0.j]
#  [-6.55426047e+00+0.j  4.69521839e-01+0.j]
#  [-3.06253324e+00+0.j  3.34653638e-02+0.j]
#  [ 1.55273962e+01+0.j -3.95038092e-01+0.j]
# ...

# %%
def eig(A):
    a1 = A[0][0]
    b1 = A[0][1]
    c1 = A[1][0]
    d1 = A[1][1]

    det = a1*d1 - c1*d1

    t = a1 + d1

    dis = t * t - 4 * det

    if dis < 0:
        print("Complex Eigenvalues")
        return

    s = dis ** 0.5

    l1 = (t + s)/2
    l2 = (t - s)/2
    
    print()

    print("Eigenvector of ", l1)

    if b1 != 0:
        x = 1
        y = (l1 - a1)/b1
    elif c1 != 0:
        y = 1
        x = (l1 - d1)/c1
    else:
        x = 1
        y = 0

    print([x, y])

    print()
    
    print("Eigenvector of ", l2)

    if b1 != 0:
        x = 1
        y = (l2 - a1)/b1
    elif c1 != 0:
        y = 1
        x = (l2 - d1)/c1
    else:
        x = 1
        y = 0

    print([x, y])
# Out:
# [[-0.45046715+0.j -0.03030993+0.j]
#  [-0.51747633+0.j  0.79068269+0.j]
#  [-0.14415709+0.j  0.10566041+0.j]
#  [-0.1015085 +0.j  0.09222312+0.j]
#  [-0.70584159+0.j -0.59517473+0.j]]

# %%
import numpy as np
import pandas as pd

X = pd.read_csv("PCA.csv")
X.values

mean = np.mean(X, axis=0)
x_center = X - mean

cov_matrix = np.cov(x_center.T)

eigenvalues, eigenvector = np.linalg.eig(cov_matrix)

idx = np.argsort(eigenvalues)[::-1]

eigenvalues = eigenvalues[idx]
eigenvector = eigenvector[:, idx]

pc = eigenvector[:, :2]

pca = x_center @ pc

print(pca)
# Out:
#                        0                   1
# 0    5.995797+ 0.000000j  0.960314+0.000000j
# 1    1.179244+ 0.000000j  1.684101+0.000000j
# 2   13.258987+ 0.000000j -0.154490+0.000000j
# 3  -14.762592+ 0.000000j  0.032188+0.000000j
# 4   -6.148001+ 0.000000j -0.991686+0.000000j
# 5   17.201181+ 0.000000j -0.560236+0.000000j
# 6  -11.041703+ 0.000000j -0.983231+0.000000j
# 7    8.187059+ 0.000000j  0.004433+0.000000j
# 8  -21.134986+ 0.000000j -0.328714+0.000000j
# 9    3.616171+ 0.000000j  0.530337+0.000000j
# 10  12.486136+ 0.000000j  0.071328+0.000000j
# 11  -6.554260+ 0.000000j  0.469522+0.000000j
# 12  -3.062533+ 0.000000j  0.033465+0.000000j
# 13  15.527396+ 0.000000j -0.395038+0.000000j
# 14 -16.580535+ 0.000000j  0.303046+0.000000j
# 15  -0.063922+ 0.000000j -0.419464+0.000000j
# 16 -10.258714+ 0.000000j  0.327276+0.000000j
# 17  19.580808+ 0.000000j -0.130259+0.000000j
# 18 -13.232964+ 0.000000j -0.027350+0.000000j
# 19   5.807432+ 0.000000j -0.425544+0.000000j

# %%
def gradient_descend(x, lr, itr):
    for i in range(itr):
        gradient = 2 * x
        x -= lr * gradient
        
    return x

print(gradient_descend(10, 0.1, 100))
# Out:
# 2.0370359763344878e-09

# %%
def multi3(A, B):

    result = [[0 for i in range(len(B[0]))] for i in range(len(A))]

    for i in range(len(A)):
        for j in range(len(B[0])):
            for k in range(len(B)):
                result[i][j] += A[i][k] * B[k][j]

    return result

A = [[20, 1, 3],
    [4, 0, 1]]

B = [[1, 6],
    [3, 4],
    [5, 6]]

print(multi3(A, B))
# Out:
# [[38, 142], [9, 30]]

# %%
def det3(A):
    a1 = A[0][0]
    a2 = A[0][1]
    a3 = A[0][2]
    b1 = A[1][0]
    b2 = A[1][1]
    b3 = A[1][2]
    c1 = A[2][0]
    c2 = A[2][1]
    c3 = A[2][2]

    det = a1*((b2*c3) - (c2*b3)) - a2*((b1*c3) - (c1*b3)) + a3*((b1*c2) - (c1*b2))

    print(det)
    return

A = [[1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]]

det3(A)
# Out:
# 0

# %%
def inv(matrix):

    det = matrix[0][0] * matrix[1][1] - matrix[0][1] * matrix[1][0]\

    return [[matrix[0][0]/det, -matrix[0][1]/det],
           [-matrix[1][0]/det, matrix[1][1]/det]]

A = [[2 ,4],
    [1, 3]]

print(inv(A))
# Out:
# [[1.0, -2.0], [-0.5, 1.5]]

# %%
import numpy as np
import pandas as pd

X = pd.read_csv("PCA.csv")
X.values

mean = np.mean(X, axis=0)
x_center = X - mean

cov_matrix = np.cov(x_center.T)

eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

idx = np.argsort(eigenvalues)[:: -1]

eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

principal_component = eigenvectors[:, :2]

pca = x_center @ principal_component

print(pca)
# Out:
#                        0                   1
# 0    5.995797+ 0.000000j  0.960314+0.000000j
# 1    1.179244+ 0.000000j  1.684101+0.000000j
# 2   13.258987+ 0.000000j -0.154490+0.000000j
# 3  -14.762592+ 0.000000j  0.032188+0.000000j
# 4   -6.148001+ 0.000000j -0.991686+0.000000j
# 5   17.201181+ 0.000000j -0.560236+0.000000j
# 6  -11.041703+ 0.000000j -0.983231+0.000000j
# 7    8.187059+ 0.000000j  0.004433+0.000000j
# 8  -21.134986+ 0.000000j -0.328714+0.000000j
# 9    3.616171+ 0.000000j  0.530337+0.000000j
# 10  12.486136+ 0.000000j  0.071328+0.000000j
# 11  -6.554260+ 0.000000j  0.469522+0.000000j
# 12  -3.062533+ 0.000000j  0.033465+0.000000j
# 13  15.527396+ 0.000000j -0.395038+0.000000j
# 14 -16.580535+ 0.000000j  0.303046+0.000000j
# 15  -0.063922+ 0.000000j -0.419464+0.000000j
# 16 -10.258714+ 0.000000j  0.327276+0.000000j
# 17  19.580808+ 0.000000j -0.130259+0.000000j
# 18 -13.232964+ 0.000000j -0.027350+0.000000j
# 19   5.807432+ 0.000000j -0.425544+0.000000j

# %%
def gradient_descend(x, lr, itr)
