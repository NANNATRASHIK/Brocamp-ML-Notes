# %%
import numpy as np

import pandas as pd

# %%
arr = np.array([85, 90, 65, 78, 55])

print(max(arr))

print(min(arr))

print(arr.mean())

print(arr + 5)

print(arr.std())
# Out:
# 90
# 55
# 74.6
# [90 95 70 83 60]
# 12.90891165048394

# %%
df = pd.DataFrame(
    {
    "name": ["Afsal", "Anu", "Rahul", "Meera"],
    "department": ["Data Science", "Data Science", "Python", "Python"],
    "marks": [85, 90, 65, 78]
}
)

df["Result"] = np.where(df["marks"] > 70, "Passed", "Failed")

print(df)
# Out:
#     name    department  marks  Result
# 0  Afsal  Data Science     85  Passed
# 1    Anu  Data Science     90  Passed
# 2  Rahul        Python     65  Failed
# 3  Meera        Python     78  Passed

# %%
ds = pd.read_csv("to send a storstudent_id,name,age,g.csv")

# %%
ds.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   to send a storstudent_id  15 non-null     int64
#  1   name                      15 non-null     str
#  2   age                       15 non-null     int64
#  3   gender                    15 non-null     str
#  4   department                15 non-null     str
#  5   maths                     15 non-null     int64
#  6   science                   15 non-null     int64
#  7   english                   15 non-null     int64
#  8   attendance                15 non-null     int64
#  9   study_hours               15 non-null     int64
#  10  city                      15 non-null     str
# dtypes: int64(7), str(4)
# memory usage: 1.4 KB

# %%
ds.isnull().sum()
# Out:
# to send a storstudent_id    0
# name                        0
# age                         0
# gender                      0
# department                  0
# maths                       0
# science                     0
# english                     0
# attendance                  0
# study_hours                 0
# city                        0
# dtype: int64

# %%
ds.head(1)
# Out:
#    to send a storstudent_id   name  age gender    department  maths  science  \
# 0                         1  Afsal   21   Male  Data Science     85       78
#
#    english  attendance  study_hours     city
# 0       80          92            5  Calicut

# %%
ds.tail(1)
# Out:
#     to send a storstudent_id    name  age gender department  maths  science  \
# 14                        15  Jithin   22   Male     Python     83       80
#
#     english  attendance  study_hours              city
# 14       82          90            5  Thrissury to be

# %%
ds.loc[ds["maths"] > 80, "name"]
# Out:
# 0       Afsal
# 1         Anu
# 5       Sneha
# 7     Fathima
# 9        Diya
# 11      Kavya
# 14     Jithin
# Name: name, dtype: str

# %%
import matplotlib.pyplot as plt

# %%
x = ds["study_hours"]

y = ds["name"]

plt.plot(x,y)

plt.ylabel("Students")
plt.xlabel("Hours")

plt.show()
