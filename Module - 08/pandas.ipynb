# %%
import pandas as pd

# %%
ages =  pd.Series([18, 27, 41, 19])

print(ages)
# Out:
# 0    18
# 1    27
# 2    41
# 3    19
# dtype: int64

# %%
df = pd.DataFrame({
    "names" : ["Shibil", "Rahul", "Rajan", "Arjun"],
    "ages" : [18, 27, 41, 19]})

df.head()
# Out:
#     names  ages
# 0  Shibil    18
# 1   Rahul    27
# 2   Rajan    41
# 3   Arjun    19

# %%
ds = pd.read_csv("practice_employees.csv")

ds.head()
# Out:
#    employee_id           name   age   department city   salary   joined_at  \
# 0          101  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 1          102      Bob Smith  32.0        Sales   LA  62000.0  2019-07-01
# 2          103    Charlie Lee  45.0  Engineering  NYC  95000.0  2015-11-23
# 3          104     Dana White  29.0    Marketing   SF  58000.0  2020-01-10
# 4          105    Ethan Brown   NaN        Sales   LA      NaN  2022-06-05
#
#    is_manager
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False

# %%
ds.tail()
# Out:
#     employee_id           name   age   department city   salary   joined_at  \
# 10          111  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 11          112    Kevin Young  52.0           HR  NYC  72000.0  2010-05-05
# 12          113     Laura Hill  24.0    Marketing   LA  50000.0  2023-01-17
# 13          114     Mike Davis  36.0        Sales   SF  64000.0  2017-10-11
# 14          115     Nina Patel  31.0  Engineering  NYC  89000.0  2020-03-03
#
#     is_manager
# 10       False
# 11        True
# 12       False
# 13       False
# 14       False

# %%
ds.sample()
# Out:
#    employee_id         name  age department city   salary   joined_at  \
# 9          110  Julia Adams  NaN         HR   SF  54000.0  2021-08-22
#
#    is_manager
# 9       False

# %%
ds.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  15 non-null     int64
#  1   name         15 non-null     str
#  2   age          13 non-null     float64
#  3   department   15 non-null     str
#  4   city         14 non-null     str
#  5   salary       13 non-null     float64
#  6   joined_at    15 non-null     str
#  7   is_manager   15 non-null     bool
# dtypes: bool(1), float64(2), int64(1), str(4)
# memory usage: 987.0 bytes

# %%
ds.describe()
# Out:
#        employee_id        age        salary
# count    15.000000  13.000000     13.000000
# mean    108.000000  33.692308  73846.153846
# std       4.472136   8.479236  15603.664921
# min     101.000000  24.000000  50000.000000
# 25%     104.500000  27.000000  62000.000000
# 50%     108.000000  32.000000  72000.000000
# 75%     111.500000  38.000000  88000.000000
# max     115.000000  52.000000  95000.000000

# %%
ds.shape
# Out:
# (15, 8)

# %%
ds.size
# Out:
# 120

# %%
ds.columns
# Out:
# Index(['employee_id', 'name', 'age', 'department', 'city', 'salary',
#        'joined_at', 'is_manager'],
#       dtype='str')

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %%
ds.dtypes
# Out:
# employee_id      int64
# name               str
# age            float64
# department         str
# city               str
# salary         float64
# joined_at          str
# is_manager        bool
# dtype: object

# %%
ds[["name", "age"]]
# Out:
#              name   age
# 0   Alice Johnson  25.0
# 1       Bob Smith  32.0
# 2     Charlie Lee  45.0
# 3      Dana White  29.0
# 4     Ethan Brown   NaN
# 5     Fiona Green  38.0
# 6     George King  41.0
# 7    Hannah Scott  27.0
# 8      Ian Wright  33.0
# 9     Julia Adams   NaN
# 10  Alice Johnson  25.0
# 11    Kevin Young  52.0
# 12     Laura Hill  24.0
# 13     Mike Davis  36.0
# 14     Nina Patel  31.0

# %%
ds["name"]
# Out:
# 0     Alice Johnson
# 1         Bob Smith
# 2       Charlie Lee
# 3        Dana White
# 4       Ethan Brown
# 5       Fiona Green
# 6       George King
# 7      Hannah Scott
# 8        Ian Wright
# 9       Julia Adams
# 10    Alice Johnson
# 11      Kevin Young
# 12       Laura Hill
# 13       Mike Davis
# 14       Nina Patel
# Name: name, dtype: str

# %%
ds.loc[0]
# Out:
# employee_id              101
# name           Alice Johnson
# age                     25.0
# department       Engineering
# city                     NYC
# salary               85000.0
# joined_at         2021-03-15
# is_manager             False
# Name: 0, dtype: object

# %%
ds.loc[0:2, ["name", "age"]]
# Out:
#             name   age
# 0  Alice Johnson  25.0
# 1      Bob Smith  32.0
# 2    Charlie Lee  45.0

# %%
ds.iloc[0:2]
# Out:
#    employee_id           name   age   department city   salary   joined_at  \
# 0          101  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 1          102      Bob Smith  32.0        Sales   LA  62000.0  2019-07-01
#
#    is_manager
# 0       False
# 1        True

# %%
ds[ds["department"] == "Sales"]
# Out:
#     employee_id          name   age department city   salary   joined_at  \
# 1           102     Bob Smith  32.0      Sales   LA  62000.0  2019-07-01
# 4           105   Ethan Brown   NaN      Sales   LA      NaN  2022-06-05
# 7           108  Hannah Scott  27.0      Sales  NYC      NaN  2023-04-01
# 13          114    Mike Davis  36.0      Sales   SF  64000.0  2017-10-11
#
#     is_manager
# 1         True
# 4        False
# 7        False
# 13       False

# %%
ds.isnull()
# Out:
#     employee_id   name    age  department   city  salary  joined_at  \
# 0         False  False  False       False  False   False      False
# 1         False  False  False       False  False   False      False
# 2         False  False  False       False  False   False      False
# 3         False  False  False       False  False   False      False
# 4         False  False   True       False  False    True      False
# 5         False  False  False       False   True   False      False
# 6         False  False  False       False  False   False      False
# 7         False  False  False       False  False    True      False
# 8         False  False  False       False  False   False      False
# 9         False  False   True       False  False   False      False
# 10        False  False  False       False  False   False      False
# 11        False  False  False       False  False   False      False
# 12        False  False  False       False  False   False      False
# ...

# %%
ds.notnull()
# Out:
#     employee_id  name    age  department   city  salary  joined_at  is_manager
# 0          True  True   True        True   True    True       True        True
# 1          True  True   True        True   True    True       True        True
# 2          True  True   True        True   True    True       True        True
# 3          True  True   True        True   True    True       True        True
# 4          True  True  False        True   True   False       True        True
# 5          True  True   True        True  False    True       True        True
# 6          True  True   True        True   True    True       True        True
# 7          True  True   True        True   True   False       True        True
# 8          True  True   True        True   True    True       True        True
# 9          True  True  False        True   True    True       True        True
# 10         True  True   True        True   True    True       True        True
# ...

# %%
#fill in missing values

ds["age"].fillna(100)
# Out:
# 0      25.0
# 1      32.0
# 2      45.0
# 3      29.0
# 4     100.0
# 5      38.0
# 6      41.0
# 7      27.0
# 8      33.0
# 9     100.0
# 10     25.0
# 11     52.0
# 12     24.0
# 13     36.0
# 14     31.0
# Name: age, dtype: float64

# %%
ds.drop(1)
# Out:
#     employee_id           name   age   department city   salary   joined_at  \
# 0           101  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 2           103    Charlie Lee  45.0  Engineering  NYC  95000.0  2015-11-23
# 3           104     Dana White  29.0    Marketing   SF  58000.0  2020-01-10
# 4           105    Ethan Brown   NaN        Sales   LA      NaN  2022-06-05
# 5           106    Fiona Green  38.0  Engineering  NaN  91000.0  2018-09-30
# 6           107    George King  41.0    Marketing   SF  67000.0  2016-02-14
# 7           108   Hannah Scott  27.0        Sales  NYC      NaN  2023-04-01
# 8           109     Ian Wright  33.0  Engineering   LA  88000.0  2019-12-19
# 9           110    Julia Adams   NaN           HR   SF  54000.0  2021-08-22
# 10          111  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 11          112    Kevin Young  52.0           HR  NYC  72000.0  2010-05-05
# ...

# %%
ds.drop_duplicates()
# Out:
#     employee_id           name   age   department city   salary   joined_at  \
# 0           101  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 1           102      Bob Smith  32.0        Sales   LA  62000.0  2019-07-01
# 2           103    Charlie Lee  45.0  Engineering  NYC  95000.0  2015-11-23
# 3           104     Dana White  29.0    Marketing   SF  58000.0  2020-01-10
# 4           105    Ethan Brown   NaN        Sales   LA      NaN  2022-06-05
# 5           106    Fiona Green  38.0  Engineering  NaN  91000.0  2018-09-30
# 6           107    George King  41.0    Marketing   SF  67000.0  2016-02-14
# 7           108   Hannah Scott  27.0        Sales  NYC      NaN  2023-04-01
# 8           109     Ian Wright  33.0  Engineering   LA  88000.0  2019-12-19
# 9           110    Julia Adams   NaN           HR   SF  54000.0  2021-08-22
# 10          111  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# ...

# %%
ds.replace("Bob Smith", "id")
# Out:
#     employee_id           name   age   department city   salary   joined_at  \
# 0           101  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 1           102             id  32.0        Sales   LA  62000.0  2019-07-01
# 2           103    Charlie Lee  45.0  Engineering  NYC  95000.0  2015-11-23
# 3           104     Dana White  29.0    Marketing   SF  58000.0  2020-01-10
# 4           105    Ethan Brown   NaN        Sales   LA      NaN  2022-06-05
# 5           106    Fiona Green  38.0  Engineering  NaN  91000.0  2018-09-30
# 6           107    George King  41.0    Marketing   SF  67000.0  2016-02-14
# 7           108   Hannah Scott  27.0        Sales  NYC      NaN  2023-04-01
# 8           109     Ian Wright  33.0  Engineering   LA  88000.0  2019-12-19
# 9           110    Julia Adams   NaN           HR   SF  54000.0  2021-08-22
# 10          111  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# ...

# %%
ds.rename(columns = {"employee_id":"id"})
# Out:
#      id           name   age   department city   salary   joined_at  \
# 0   101  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 1   102      Bob Smith  32.0        Sales   LA  62000.0  2019-07-01
# 2   103    Charlie Lee  45.0  Engineering  NYC  95000.0  2015-11-23
# 3   104     Dana White  29.0    Marketing   SF  58000.0  2020-01-10
# 4   105    Ethan Brown   NaN        Sales   LA      NaN  2022-06-05
# 5   106    Fiona Green  38.0  Engineering  NaN  91000.0  2018-09-30
# 6   107    George King  41.0    Marketing   SF  67000.0  2016-02-14
# 7   108   Hannah Scott  27.0        Sales  NYC      NaN  2023-04-01
# 8   109     Ian Wright  33.0  Engineering   LA  88000.0  2019-12-19
# 9   110    Julia Adams   NaN           HR   SF  54000.0  2021-08-22
# 10  111  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 11  112    Kevin Young  52.0           HR  NYC  72000.0  2010-05-05
# 12  113     Laura Hill  24.0    Marketing   LA  50000.0  2023-01-17
# ...

# %%
ds.iloc[0,2]
# Out:
# np.float64(25.0)

# %%
ds["Passed"] = True

ds["Bonus"] = (ds["salary"]*0.10)

ds.head(15)
# Out:
#     employee_id           name   age   department city   salary   joined_at  \
# 0           101  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 1           102      Bob Smith  32.0        Sales   LA  62000.0  2019-07-01
# 2           103    Charlie Lee  45.0  Engineering  NYC  95000.0  2015-11-23
# 3           104     Dana White  29.0    Marketing   SF  58000.0  2020-01-10
# 4           105    Ethan Brown   NaN        Sales   LA      NaN  2022-06-05
# 5           106    Fiona Green  38.0  Engineering  NaN  91000.0  2018-09-30
# 6           107    George King  41.0    Marketing   SF  67000.0  2016-02-14
# 7           108   Hannah Scott  27.0        Sales  NYC      NaN  2023-04-01
# 8           109     Ian Wright  33.0  Engineering   LA  88000.0  2019-12-19
# 9           110    Julia Adams   NaN           HR   SF  54000.0  2021-08-22
# 10          111  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# ...

# %%
ds.isnull().sum()
# Out:
# employee_id    0
# name           0
# age            2
# department     0
# city           1
# salary         2
# joined_at      0
# is_manager     0
# Passed         0
# Bonus          2
# dtype: int64

# %%
ds["age"].fillna(ds["age"].mean())
# Out:
# 0     25.000000
# 1     32.000000
# 2     45.000000
# 3     29.000000
# 4     33.692308
# 5     38.000000
# 6     41.000000
# 7     27.000000
# 8     33.000000
# 9     33.692308
# 10    25.000000
# 11    52.000000
# 12    24.000000
# 13    36.000000
# 14    31.000000
# Name: age, dtype: float64

# %%
ds.sort_values("age")
# Out:
#     employee_id           name   age   department city   salary   joined_at  \
# 12          113     Laura Hill  24.0    Marketing   LA  50000.0  2023-01-17
# 0           101  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 10          111  Alice Johnson  25.0  Engineering  NYC  85000.0  2021-03-15
# 7           108   Hannah Scott  27.0        Sales  NYC      NaN  2023-04-01
# 3           104     Dana White  29.0    Marketing   SF  58000.0  2020-01-10
# 14          115     Nina Patel  31.0  Engineering  NYC  89000.0  2020-03-03
# 1           102      Bob Smith  32.0        Sales   LA  62000.0  2019-07-01
# 8           109     Ian Wright  33.0  Engineering   LA  88000.0  2019-12-19
# 13          114     Mike Davis  36.0        Sales   SF  64000.0  2017-10-11
# 5           106    Fiona Green  38.0  Engineering  NaN  91000.0  2018-09-30
# 6           107    George King  41.0    Marketing   SF  67000.0  2016-02-14
# ...

# %%
ds.groupby("city")["salary"].mean()
# Out:
# city
# LA     66666.666667
# NYC    85200.000000
# SF     60750.000000
# Name: salary, dtype: float64

# %%
data1 = {
    "id" : [1, 2, 3],
    "age" : [19, 32, 24]
       }

data2 = {
    "id" : [1, 2, 3],
    "roll_no" : [19, 32, 24]
        }

df1 = pd.DataFrame(data1)

df2 = pd.DataFrame(data2)

pd.merge(
    df1, df2, on="id"
)
# Out:
#    id  age  roll_no
# 0   1   19       19
# 1   2   32       32
# 2   3   24       24

# %%
data1 = {
    "id" : [1, 2, 3],
    "age" : [19, 32, 24]
       }

data2 = {
    "id" : [1, 2, 3],
    "roll_no" : [19, 32, 24]
        }

pd.concat([df1, df2])
# Out:
#    id   age  roll_no
# 0   1  19.0      NaN
# 1   2  32.0      NaN
# 2   3  24.0      NaN
# 0   1   NaN     19.0
# 1   2   NaN     32.0
# 2   3   NaN     24.0

# %%
ds.to_csv("output_1.csv", index=False)

# %%
ages = pd.Series(
    ["Rahul","Anu","John"],
    [18,20,22],
)

print(ages)
# Out:
# 18    Rahul
# 20      Anu
# 22     John
# dtype: str

# %%
ages = pd.Series(
    ["Rahul","Anu","John"],
    [18,20,22],
)

print(ages)
# Out:
# 18    Rahul
# 20      Anu
# 22     John
# dtype: str

# %%
ages = pd.Series(
    ["Rahul","Anu","John"],
    [18,20,22],
)

print(ages)
# Out:
# 18    Rahul
# 20      Anu
# 22     John
# dtype: str

# %%
ages = pd.Series(
    ["Rahul","Anu","John"],
    [18,20,22],
)

print(ages)
# Out:
# 18    Rahul
# 20      Anu
# 22     John
# dtype: str

# %%
ages = pd.Series(
    ["Rahul","Anu","John"],
    [18,20,22],
)

print(ages)
# Out:
# 18    Rahul
# 20      Anu
# 22     John
# dtype: str

# %%
ages = pd.Series(
    ["Rahul","Anu","John"],
    [18,20,22],
)

print(ages)
# Out:
# 18    Rahul
# 20      Anu
# 22     John
# dtype: str

# %%
ages = pd.Series(
    ["Rahul","Anu","John"],
    [18,20,22],
) 

print(ages)
# Out:
# 18    Rahul
# 20      Anu
# 22     John
# dtype: str

# %%
ds.groupby("department")["salary"].agg(["mean", "max"])
# Out:
#                      mean      max
# department
# Engineering  88833.333333  95000.0
# HR           63000.000000  72000.0
# Marketing    58333.333333  67000.0
# Sales        63000.000000  64000.0

# %%
ds.iloc[0]
# Out:
# employee_id              101
# name           Alice Johnson
# age                     25.0
# department       Engineering
# city                     NYC
# salary               85000.0
# joined_at         2021-03-15
# is_manager             False
# Passed                  True
# Bonus                 8500.0
# Name: 0, dtype: object

# %%
df1 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df2 = pd.DataFrame({'City': ['New York', 'Los Angeles'], 'Salary': [70000, 80000]})

# Stack horizontally
result = pd.concat([df1, df2], axis=1)
print(result)
# Out:
#     Name  Age         City  Salary
# 0  Alice   25     New York   70000
# 1    Bob   30  Los Angeles   80000

# %%
import pandas as pd

df1 = pd.DataFrame({'Name': ['Alice', 'Bob'], 'Age': [25, 30]})
df2 = pd.DataFrame({'Name': ['Charlie', 'David'], 'Age': [35, 40]})

# Stack vertically
result = pd.concat([df1, df2])
print(result)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 0  Charlie   35
# 1    David   40

# %%
df1 = pd.DataFrame({
    "Name": ["Alice", "Bob"]
})

df2 = pd.DataFrame({
    "Marks": [90, 85]
})

result = pd.concat([df1, df2], axis=1)

print(result)
# Out:
#     Name  Marks
# 0  Alice     90
# 1    Bob     85

# %%
print("Hello World!")
# Out:
# Hello World!
